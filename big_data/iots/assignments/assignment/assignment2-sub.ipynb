# %%
import paho.mqtt.client as mqtt
MQTT_HOST = "broker.mqttdashboard.com"
MQTT_PORT = 1883
MQTT_KEEPALIVE_INTERVAL = 45 #45 seconds
MQTT_TOPIC = "CPE_HOUSE/LAUNDRY/#"

def on_connect(self,client, userdata, rc):
    print("MQTT Connected.")
    self.subscribe(MQTT_TOPIC)
    # add more subscribe ...
    # e.g.;
    # self.subscribe("CPE_DEMO_HOUSE/room2/#")

def on_message(client, userdata, msg):
    print("message received...")
    print(msg.topic + " "+ str(msg.qos) + " " + str(msg.payload.decode("utf-8","strict")))

client = mqtt.Client()
client.on_connect = on_connect
client.on_message = on_message
client.connect(MQTT_HOST)
client.loop_forever()
# Out:
# /tmp/nix-shell.d4q1AX/ipykernel_53780/156592542.py:18: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()
# MQTT Connected.
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 63.4
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/ 0 {"Temperature": 30, "Humidity": 60, "Light": 138}
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 23.7
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 25.6
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 72.6
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 24.8
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 82.6
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 24.4
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 59.5
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 22.8
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 58.1
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 25.9
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 57.1
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 20.8
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 72.9
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 26.4
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 80.0
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 29.8
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 65.2
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 28.2
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 66.1
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 26.6
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 59.1
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 20.8
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 65.4
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 24.2
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 67.4
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 24.8
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 79.9
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 25.4
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 73.5
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 24.7
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 64.7
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# message received...
# CPE_HOUSE/LAUNDRY/temperature 0 21.6
# message received...
# CPE_HOUSE/LAUNDRY/humidity 0 63.3
# message received...
# CPE_HOUSE/LAUNDRY/LED/set 0 0
# message received...
# CPE_HOUSE/LAUNDRY/LED/status 0 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 22
#      20 client.on_message = on_message
#      21 client.connect(MQTT_HOST)
# ---> 22 client.loop_forever()
#
# File /nix/store/1a27n5w7h6wffgyraszby3qqwgy92r91-dev-env/lib/python3.11/site-packages/paho/mqtt/client.py:2297, in Client.loop_forever(self, timeout, retry_first_connection)
#    2295 rc = MQTTErrorCode.MQTT_ERR_SUCCESS
#    2296 while rc == MQTTErrorCode.MQTT_ERR_SUCCESS:
# -> 2297     rc = self._loop(timeout)
#    2298     # We don't need to worry about locking here, because we've
#    2299     # either called loop_forever() when in single threaded mode, or
#    2300     # in multi threaded mode when loop_stop() has been called and
#    2301     # so no other threads can access _out_packet or _messages.
#    2302     if (self._thread_terminate is True
#    2303         and len(self._out_packet) == 0
#    2304             and len(self._out_messages) == 0):
#
# File /nix/store/1a27n5w7h6wffgyraszby3qqwgy92r91-dev-env/lib/python3.11/site-packages/paho/mqtt/client.py:1663, in Client._loop(self, timeout)
#    1660     rlist = [self._sock, self._sockpairR]
#    1662 try:
# -> 1663     socklist = select.select(rlist, wlist, [], timeout)
#    1664 except TypeError:
#    1665     # Socket isn't correct type, in likelihood connection is lost
#    1666     # ... or we called disconnect(). In that case the socket will
#    (...)   1669     # rc != MQTT_ERR_SUCCESS and we don't want state to change from
#    1670     # mqtt_cs_disconnecting.
#    1671     if self._state not in (_ConnectionState.MQTT_CS_DISCONNECTING, _ConnectionState.MQTT_CS_DISCONNECTED):
#
# KeyboardInterrupt:
